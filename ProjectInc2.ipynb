# %% [markdown]
# <a href="https://colab.research.google.com/github/prathyusha-reddy-arch/DataVisualisation/blob/main/ProjectInc2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# scaling 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# kmeans clustering 
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from yellowbrick.cluster import SilhouetteVisualizer

# multivariate linear regression
from sklearn import linear_model

# geo data

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 42.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 48.5 MB/s eta 0:00:00
# ...

# %%
# geo data
import geopandas as gpd
from geopandas import GeoDataFrame as gdf
import plotly.express as px

# %%
data=pd.read_csv('/content/CountryData.csv')
print(data.head())
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
data.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
def inflation_rate(low_rate,high_rate):
  filtered_countries = []
  filtered_inflation_rates = []
  count=0
  for i in range(len(data.country)):
     if data.inflation[i] <high_rate and data.inflation[i] >=low_rate:
        filtered_countries.append(data.country[i])
        filtered_inflation_rates.append(data.inflation[i])
        count=count+1
   # create a bar chart with the filtered data
  plt.bar(filtered_countries, filtered_inflation_rates, linewidth=9,align='edge',width=0.5) 
  # add labels and title
  plt.xlabel("Countries")
  plt.ylabel("Inflation Rate")
  str
  plt.title("Inflation Rates by Country (less than "+str(high_rate) +") and greater than "+ str(low_rate) +" is "   + str(count))

  plt.xticks(rotation=90,fontsize=8)

  # show the plot
  plt.show()

# %%
inflation_rate(0,5)

# %%
inflation_rate(5,10)

# %%
inflation_rate(10,15)

# %%
inflation_rate(15,20)

# %%
inflation_rate(20,30)

# %%
def childmort_rate(low_rate,high_rate):
  filtered_countries = []
  filtered_childmort_rates = []
  count=0
  for i in range(len(data.country)):
     if data.child_mort[i] <high_rate and data.child_mort[i] >=low_rate:
        filtered_countries.append(data.country[i])
        filtered_childmort_rates.append(data.child_mort[i])
        count=count+1
   # create a bar chart with the filtered data
  plt.bar(filtered_countries, filtered_childmort_rates, linewidth=9,align='edge',width=0.5) 
  # add labels and title
  plt.xlabel("Countries")
  plt.ylabel("childmort Rate")
  str
  plt.title("childmort Rates by Country (less than "+str(high_rate) +") and greater than "+ str(low_rate) +" is "   + str(count))

  plt.xticks(rotation=90,fontsize=8)

  # show the plot
  plt.show()

# %%
childmort_rate(0,15)

# %%
def factors_pie(country):
 myLabels=["Child_mort","exports","health","imports","inflation","total_fer"]
 colors = ['#1ABC9C','#F1C40F','#EDBB99','#ABEBC6','#A52A2A','#00FF00']
 for i in range(len(data.country)):
   if data.country[i]==country: 
    factors=[data.child_mort[i],data.exports[i],data.health[i],data.imports[i],data.inflation[i],data.total_fer[i]]
 plt.pie(factors,labels=myLabels,colors=colors)
 plt.legend(loc='upper right')
 plt.title('Factors effecting poverty in  '+country)
 plt.show()

# %%
factors_pie("Australia")

# %%
factors_pie("Italy")
